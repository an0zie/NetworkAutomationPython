# %% [markdown]
# <a href="https://colab.research.google.com/github/an0zie/NetworkAutomationPython/blob/main/DataScieneceLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TITLE

# %% [markdown]
# ## SUBTITLE 1.1

# %%
print("hello world")
# Out:
# hello world

# %%
"hello world"
# Out:
# 'hello world'

# %%
#   printing my name
print("Michael")
# Out:
# Michael

# %%
type("hello world ")
# Out:
# str

# %%
"hello world".upper()
# Out:
# 'HELLO WORLD'

# %%
"hello world".lower()
# Out:
# 'hello world'

# %%
"hello world".capitalize()
# Out:
# 'Hello world'

# %%
"hello world".title()
# Out:
# 'Hello World'

# %%
# how many times l is in the string
"hello world".count('l')
# Out:
# 3

# %%
# replace a word in a string with another word
"hello world".replace('l','r')
# Out:
# 'herro worrd'

# %% [markdown]
# # VARIABLE

# %%
message_1 = "im learning python"
print(message_1)
# Out:
# im learning python

# %%
message_2 = " and its fun "

# %%
message_2
# Out:
# ' and its fun '

# %%
message = message_1 + message_2

# %%
message
# Out:
# 'im learning python and its fun '

# %%
f'Hello world {message_1} and {message_2}'
# Out:
# 'Hello world im learning python and  and its fun '

# %% [markdown]
# # 4 LIST

# %%
# lists in python
countries =['United states', 'Germany', 'india','China']

# %%
countries
# Out:
# ['United states', 'Germany', 'india', 'China']

# %%
# in a list you can combine integers (numbers) and strings
count = ['united',2 ,'color45','happy']

# %%
count
# Out:
# ['united', 2, 'color45', 'happy']

# %%
# indexing
print(countries[0])
print(countries[1])
print(countries[2])
print(countries[3])
# Out:
# United states
# Germany
# india
# China

# %%
# negative indexing : starting from the last element  to the first element or what ever element you want to stop at in a list
print(countries[-1]) # the last element
print(countries[-2])
print(countries[-3])
print(countries[-4])
# Out:
# China
# india
# Germany
# United states

# %%
# slicing : accessing parts of a list, a slice  is a subset of list elements
countries[0:4] # list_name[start:stop]
# Out:
# ['United states', 'Germany', 'india', 'China']

# %%
countries [1:4]
# Out:
# ['Germany', 'india', 'China']

# %%
# another way of wrting a slice that you want to make sure it ends at the end of the list is  list_name[start:]


countries[1:]
# Out:
# ['Germany', 'india', 'China']

# %%
# another way of wrting a slice that you want to make sure it begins at the beginning of the list is  list_name[:stop]

countries[:4]
# Out:
# ['United states', 'Germany', 'india', 'China']

# %% [markdown]
# # ADDING ELEMENTS TO A LIST

# %%
countries
# Out:
# ['United states', 'Germany', 'india', 'China']

# %%
# used to add elemets to a list
countries.append('Aura salad')

# %%
countries
# Out:
# ['United states', 'Germany', 'india', 'China', 'Aura salad', 'Aura salad']

# %%
# addding an element in a certain position
countries.insert(0,'Canada') # here we wanted it in position 0 index[0] which is the first position

# %%
countries
# Out:
# ['Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'United states',
#  'Germany',
#  'india',
#  'China',
#  'Aura salad',
#  'Aura salad']

# %%
# we can join 2 list with the "+" sign like we did for strings
countriesss = countries + count

# %%
countriesss
# Out:
# ['Canada',
#  'Canada',
#  'Canada',
#  'United states',
#  'Germany',
#  'india',
#  'China',
#  'Aura salad',
#  'Aura salad',
#  'united',
#  2,
#  'color45',
#  'happy']

# %%
countries.remove('Canada')

# %%
countries
# Out:
# ['Canada',
#  'Canada',
#  'Canada',
#  'United states',
#  'Germany',
#  'india',
#  'China',
#  'Aura salad',
#  'Aura salad']

# %%
# so here you add 2 or more list  but there are "[]" to show which lists you added
nested_list=[countries, count]

# %%
nested_list
# Out:
# [['Canada',
#   'Canada',
#   'Canada',
#   'United states',
#   'Germany',
#   'india',
#   'China',
#   'Aura salad',
#   'Aura salad'],
#  ['united', 2, 'color45', 'happy']]

# %%
# removing a element from a list
countries.remove('Canada')

# %%
countries
# Out:
# ['Canada',
#  'United states',
#  'Germany',
#  'india',
#  'China',
#  'Aura salad',
#  'Aura salad']

# %%
# you can also  remove an element by its index
countries.pop(-1) # the "-1" is the index of the element which in this case is the last element in a list
# Out:
# 'Aura salad'

# %%
countries
# Out:
# ['Canada', 'United states', 'Germany', 'india', 'China', 'Aura salad']

# %%
# you can also use "del " to remove a specific element with its indexbut unlike the ".pop" it doesnt show what element is being removed
del countries[0]

# %%
countries
# Out:
# ['United states', 'Germany', 'india', 'China', 'Aura salad']

# %% [markdown]
# # SORTING A LIST

# %%
numbers = [1,3,5,6,8,7,9,4,2]

# %%
# used to  sort numbers from smallest to the largest
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# here we want to sort the elements of a string in descending order
numbers = [1,3,5,6,8,7,9,4,2]
numbers.sort(reverse=True)# this is to sort it in descending order (largest to smallest)

# %%
numbers
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# # updating an element

# %%
# this is used to update the value of an element in a string to a  new  element
numbers[0]=1000

# %%
numbers
# Out:
# [1000, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
numbers[-1]=30

# %%
numbers
# Out:
# [1000, 8, 7, 6, 5, 4, 3, 2, 30]

# %% [markdown]
# # copying a list

# %%
countries[:]# this means we want the whole list
# Out:
# ['United states', 'Germany', 'india', 'China', 'Aura salad']

# %%
new_list =countries[:]

# %%
new_list
# Out:
# ['United states', 'Germany', 'india', 'China', 'Aura salad']

# %%
new_list_2= countries.copy() # used to make a copy of a list so you can use for other purposes

# %%
new_list_2
# Out:
# ['United states', 'Germany', 'india', 'China', 'Aura salad']

# %% [markdown]
# # DICTIONARY

# %%
# A DICTIONARY IS AN ORDERED COLLECTION OF ITEMS USED TO STORE DATA VALUES AND IT CONTAINS A KEY AND VALUE
my_dict={'key1':'value1','key2':'value2'}

# %%
my_data={'name':'Michael','Age':22} # you can mix different data types in a dictionary as you can see in our example

# %%
my_data
# Out:
# {'name': 'Michael', 'Age': 22}

# %%
my_data.keys()# used to get the keys of the dictionary
# Out:
# dict_keys(['name', 'Age'])

# %%
my_data.values() #used to get the values of the dictionary
# Out:
# dict_values(['Michael', 22])

# %%
my_data.items() # used to show the items (the ordered data stored in a dictionary)
# Out:
# dict_items([('name', 'Michael'), ('Age', 22)])

# %%
my_data['height']=1.7 # used to add a new item to the dictionary

# %%
my_data.items()
# Out:
# dict_items([('name', 'Michael'), ('Age', 22), ('height', 1.7)])

# %%
my_data.update({'height': 1.8}) # used to update the value of a key in a dictionary

# %%
my_data.items()
# Out:
# dict_items([('name', 'Michael'), ('Age', 22), ('height', 1.8)])

# %% [markdown]
# # COPY A DICTIONARY

# %%
new_dict = my_data.copy()

# %%
new_dict
# Out:
# {'name': 'Michael', 'Age': 22, 'height': 1.8}

# %% [markdown]
# # removing an element in a dictionary

# %%
my_data.pop('name')
# Out:
# 'Michael'

# %%
my_data
# Out:
# {'Age': 22, 'height': 1.8}

# %%
del my_data['Age']# another  of removing elemts from a dictionary

# %%
my_data
# Out:
# {'height': 1.8}

# %%
my_data.clear() # this is used to clear all elements from the dictionary

# %%
my_data
# Out:
# {}

# %% [markdown]
# # IF STATEMENTS

# %%
# executes a block of code if the conditions are met
#if <condition>:
#    <code>
#elif <condition>:
#    <code>
#else :
#    <code>

# %%
age = 15

if age >= 18 :
    print('youre an adult')
elif age>=14 and age<=17: # "and "here is a logical operator
    print('youre a teen')
else:
    print('youre a child')
# Out:
# youre a teen

# %% [markdown]
# # FOR LOOP

# %%
# here it does an iteration specific number of times
#for <variable > in <list>:
 #   <code>

# %%
countries
# Out:
# ['United states', 'Germany', 'india', 'China', 'Aura salad']

# %%
for country in countries :
    print(country)
# Out:
# United states
# Germany
# india
# China
# Aura salad

# %%
# enumerate : it is used with a for loop and returns the number of the loop
for i,country in enumerate (countries) :
    print(i)
    print(country)
# Out:
# 0
# United states
# 1
# Germany
# 2
# india
# 3
# China
# 4
# Aura salad

# %%
my_dataa={'name':'Michael','Age':22}

# %%
my_dataa
# Out:
# {'name': 'Michael', 'Age': 22}

# %%
# looping through a dictionary
for key, value in my_dataa.items():
    print(key)
    print(value)
# Out:
# name
# Michael
# Age
# 22

# %% [markdown]
# # FUNCTION

# %%
# a function is a block of code that only runs when it is called
# def function(<parmas>):
 #   <code>
 #   return <data>

# %%
def sum_values(a,b):
    x = a+b
    return x

# %%
sum_values(1,3)
# Out:
# 4

# %% [markdown]
# # BUILT-IN FUNCTIONS

# %%
countries
# Out:
# ['United states', 'Germany', 'india', 'China', 'Aura salad']

# %%
len(countries) # a built in function used to calculate the length of an iterable object(list)
# Out:
# 5

# %%
numbersss = [1,4,6,99,34,37]

# %%
max(numbersss) # built in function used to calculate the max of values (integers mostly )
# Out:
# 99

# %%
min(numbersss)# built in function used to calculate the min of values (integers mostly )
# Out:
# 1

# %%
type (numbersss) # gives the type of an object like here numbersss is a list
# Out:
# list

# %%
for i in range(1,10,2):
    print (i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # MODULE

# %%
import

# %% [markdown]
# # OS MODULE

# %%
import os

# %%
os.getcwd()# we get the directory our jupyter notebook file is located ,the"cwd" means current working directory
# Out:
# 'C:\\Users\\DELL'

# %%
os.listdir() # list all the elements in the folder (in this case DELL ) WHERE THIS JUPYTER FILE IS LOCATED
# Out:
# ['.anaconda',
#  '.android',
#  '.antigravity',
#  '.bash_history',
#  '.claude',
#  '.claude.json',
#  '.conda',
#  '.continuum',
#  '.copilot',
#  '.cursor',
#  '.docker',
#  '.emulator_console_auth_token',
#  '.gemini',
#  '.gitconfig',
#  '.gradle',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jdks',
#  '.jupyter',
#  '.m2',
#  '.matplotlib',
#  '.ms-ad',
#  '.node_repl_history',
#  '.packettracer',
#  '.python_history',
#  '.VirtualBox',
#  '.virtual_documents',
#  '.vscode',
#  'anaconda3',
#  'anaconda_projects',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'blockchain_iot_integrity',
#  'Cisco Packet Tracer 8.2.2',
#  'Contacts',
#  'Cookies',
#  'DATASCIENECELEARNING',
#  'DataScieneceLearning.ipynb',
#  'db_backup',
#  'db_backup_script',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'GNS3',
#  'IdeaProjects',
#  'IdeaSnapshots',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'maxima',
#  'Music',
#  'My Documents',
# ...

# %%
os.makedirs("moree_learning") # makes a new folder

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.antigravity',
#  '.bash_history',
#  '.claude',
#  '.claude.json',
#  '.conda',
#  '.continuum',
#  '.copilot',
#  '.cursor',
#  '.docker',
#  '.emulator_console_auth_token',
#  '.gemini',
#  '.gitconfig',
#  '.gradle',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jdks',
#  '.jupyter',
#  '.m2',
#  '.matplotlib',
#  '.ms-ad',
#  '.node_repl_history',
#  '.packettracer',
#  '.python_history',
#  '.VirtualBox',
#  '.virtual_documents',
#  '.vscode',
#  'anaconda3',
#  'anaconda_projects',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'blockchain_iot_integrity',
#  'Cisco Packet Tracer 8.2.2',
#  'Contacts',
#  'Cookies',
#  'DATASCIENECELEARNING',
#  'DataScieneceLearning.ipynb',
#  'db_backup',
#  'db_backup_script',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'GNS3',
#  'IdeaProjects',
#  'IdeaSnapshots',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'maxima',
#  'more_learning',
#  'Music',
# ...

# %% [markdown]
# # INTRODUCTION TO PANDAS AND NUMPY

# %% [markdown]
# ## PANDA

# %% [markdown]
# THIS ALLOWS TO CLEAN DATA , WRANGLE DATA , MAKE VISUALISATIONS AND MORE, THINK OF IT AS A " SUPER CHARGED MICROSOFT EXCEL "
#
# BENEFITS OF PANDAS VS EXCEL
# 1. LIMITED BY SIZE : EXCEL CANT HANDLE 1 MILLION ROWS BUT PYTHON CAN HANDLE MILLIONS OF ROWS
# 2. COMPLEX DATA TRANSFORMATION : PYTON CAN HANDLE COMPLEX COMPUTATION
# 3. AUTOMATION
# 4. CROSS PLATFORM CAPABILITIES : PYTHON REMAINS THE REGARDLESS OF ANY SYSTEM YOU CHNAGE TO
#
#
# ARRAYS: 1-DIMENSIONAL ARRAY (SERIES) AND 2-DIMENSIONAL ARRAY (DATAFRAME)
# AND THEY ARE THE 2 IMPORTNAT STRUCTURES IN PANDAS AND IN PANDAS  WE MAINLY USE MORE OF DATAFRAME AS A PANDAS DATAFRAME IS EQUIVALENT TO AN EXCEL SPREADSHEET( WITH ROWS AND COLUMN(ALSO KNOWN AS SERIES IN PANDA DATAFRAME)
#
# THE COLUMN NAME IS CALLED FEATURES
# AND THE ROW NAME IS CALLED OBSERVATION
#
# -- PANDAS TERMINOLOGY
#    EXCEL    |         PANDAS
# 1. worksheet |      Dataframe
# 2. column     |      series
# 3. row heading |    index
# 4.  row        |      row
# 5.  Empty cell  |     NaN
#
# WE CREATE A DATAFRAME WITH ARRAYS
# TO USE ARRAYS WE USE A LIBRARY CALLED "NUM.py" AND Num.py is what is  under the hood of PANDAS
#
# EXAMPLE OF NUM.py ARRAY
# NUM.py Array
# np.array([[1,4],[2,5],[3,6]])

# %% [markdown]
# ## How to create a dataframe

# %% [markdown]
# firstly  we must always import both pandas and numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Option1

# %%
# creating an array
data = np.array([[1,3],[2,5],[6,7]])

# %%
# creating a dataframe
df = pd.DataFrame(data,index=['row1','row2','row3'],columns=['col1','col2'] )

# %%
# showing the dataframe
df
# Out:
#       col1  col2
# row1     1     3
# row2     2     5
# row3     6     7

# %% [markdown]
# # OPTION 2

# %%
#creating an array with list shape
data = [1,3],[2,5],[6,7]

# %%
#creating a dataframe
dff = pd.DataFrame(data,index=['row1','row2','row3'],columns=['col1','col2'] )

# %%
#showing the dataframe
dff
# Out:
#       col1  col2
# row1     1     3
# row2     2     5
# row3     6     7

# %% [markdown]
# #  2 CREATING A DATAFRAME FROM A DICTIONARY

# %%
# lists used for this example
state =['california','texas','florida','new york']
population=[100000,200000,300000,400000]

# %%
# storing lists within a dictionary
my_states={'States': state , 'Population':population}

# %%
# creating the dataframe
dwr = pd.DataFrame(my_states,index=['state1','state2','state3','state4'],columns=['States','Population'] )

# %%
# showing the dataframe
dwr
# Out:
#             States  Population
# state1  california      100000
# state2       texas      200000
# state3     florida      300000
# state4    new york      400000

# %% [markdown]
# # 3 CREATING A DATAFRAME FROM CSV FILE

# %%
# READING THE CSV FILE
webs=pd.read_csv('C:/Users/DELL/Downloads/student_performance_data.csv')

# %%
webs
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
# SHOW FIRST 5 ROWS IN  A DATAFRAMES
webs.head() # the ".head()" shows the first 5 rows of the dataframe
# Out:
#    student_id  gender  study_hours_per_day  attendance_percentage  \
# 0      100000    Male                 4.54                  69.98
# 1      100001  Female                 5.26                  84.80
# 2      100002    Male                 8.69                  73.76
# 3      100003    Male                 4.06                  45.00
# 4      100004    Male                 8.83                  51.13
#
#    assignment_score  midterm_score  final_exam_score  participation_score  \
# 0             36.47          70.70             53.10                17.96
# 1             34.25          27.92             87.17                11.29
# 2             72.29          70.92             99.61                76.10
# 3             97.63          31.73             88.85                33.55
# 4             65.19          78.28             54.23                88.99
#
#   internet_access extra_classes parent_education  sleep_hours  overall_score  \
# ...

# %%
# show last 5 rows in a dataframe
webs.tail()
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# 9995             60.41          39.51             66.43                44.97
# 9996             62.45          48.96             81.40                45.11
# 9997             67.08          51.51             87.58                65.49
# 9998             97.73          46.51             75.49                61.21
# 9999             93.33          88.99             85.32                36.14
#
#      internet_access extra_classes parent_education  sleep_hours  \
# ...

# %%
# show first n rows in a dataframe
webs.head(10)# here i want to see the first 10 rows
# Out:
#    student_id  gender  study_hours_per_day  attendance_percentage  \
# 0      100000    Male                 4.54                  69.98
# 1      100001  Female                 5.26                  84.80
# 2      100002    Male                 8.69                  73.76
# 3      100003    Male                 4.06                  45.00
# 4      100004    Male                 8.83                  51.13
# 5      100005  Female                 1.79                  53.16
# 6      100006    Male                 7.99                  55.47
# 7      100007    Male                 8.63                  73.92
# 8      100008    Male                 2.64                  70.24
# 9      100009  Female                 4.87                  52.19
#
#    assignment_score  midterm_score  final_exam_score  participation_score  \
# 0             36.47          70.70             53.10                17.96
# 1             34.25          27.92             87.17                11.29
# ...

# %%
# show last n rows in a dataframe
webs.tail(10)# here i want to see the last 10 rows
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 9990      109990  Female                 9.45                  72.21
# 9991      109991  Female                 6.22                  52.90
# 9992      109992  Female                 3.14                  94.95
# 9993      109993  Female                 4.59                  51.37
# 9994      109994  Female                 7.82                  42.91
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# 9990             43.71          56.67             60.99                51.35
# ...

# %%
# getting access to the shape attribute
# displays the all rows of the dataframe
webs.shape # shows the number of rows and columns
# Out:
# (10000, 14)

# %%
#display n rows
pd.set_option('display.max_rows',1000)
webs
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %% [markdown]
# # attributes

# %% [markdown]
# these are values associaated with an object (referenced by name using dotted expressions) df.column  "column "is the attribute of object "df"(dataframe name  in this case )

# %%
# getting access to the shape attribute
webs.shape
# Out:
# (10000, 14)

# %%
# getting access to the index attribute
webs.index # the rows of the dataframe
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
#getting access to the column attribute
webs.columns # the columns of the dataframe
# Out:
# Index(['student_id', 'gender', 'study_hours_per_day', 'attendance_percentage',
#        'assignment_score', 'midterm_score', 'final_exam_score',
#        'participation_score', 'internet_access', 'extra_classes',
#        'parent_education', 'sleep_hours', 'overall_score', 'grade'],
#       dtype='object')

# %%
#data types of each column
webs.dtypes
# Out:
# student_id                 int64
# gender                    object
# study_hours_per_day      float64
# attendance_percentage    float64
# assignment_score         float64
# midterm_score            float64
# final_exam_score         float64
# participation_score      float64
# internet_access           object
# extra_classes             object
# parent_education          object
# sleep_hours              float64
# overall_score            float64
# grade                     object
# dtype: object

# %% [markdown]
# # METHODS
# a function which is defined inside a class body
# example
# df.head() df is the dataframe name in this case as webs is the dataframe name in your own

# %%
# showing the first 5 columns
webs.head()
# Out:
#    student_id  gender  study_hours_per_day  attendance_percentage  \
# 0      100000    Male                 4.54                  69.98
# 1      100001  Female                 5.26                  84.80
# 2      100002    Male                 8.69                  73.76
# 3      100003    Male                 4.06                  45.00
# 4      100004    Male                 8.83                  51.13
#
#    assignment_score  midterm_score  final_exam_score  participation_score  \
# 0             36.47          70.70             53.10                17.96
# 1             34.25          27.92             87.17                11.29
# 2             72.29          70.92             99.61                76.10
# 3             97.63          31.73             88.85                33.55
# 4             65.19          78.28             54.23                88.99
#
#   internet_access extra_classes parent_education  sleep_hours  overall_score  \
# ...

# %%
# showing the info of the dataframe
webs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             10000 non-null  int64
#  1   gender                 10000 non-null  object
#  2   study_hours_per_day    10000 non-null  float64
#  3   attendance_percentage  10000 non-null  float64
#  4   assignment_score       10000 non-null  float64
#  5   midterm_score          10000 non-null  float64
#  6   final_exam_score       10000 non-null  float64
#  7   participation_score    10000 non-null  float64
#  8   internet_access        10000 non-null  object
#  9   extra_classes          10000 non-null  object
#  10  parent_education       10000 non-null  object
#  11  sleep_hours            10000 non-null  float64
#  12  overall_score          10000 non-null  float64
#  13  grade                  10000 non-null  object
# ...

# %%
# describing basic statistics of the dataframe
webs.describe()
# Out:
#          student_id  study_hours_per_day  attendance_percentage  \
# count   10000.00000         10000.000000           10000.000000
# mean   104999.50000             5.467825              70.493817
# std      2886.89568             2.594134              17.295607
# min    100000.00000             1.000000              40.000000
# 25%    102499.75000             3.220000              55.640000
# 50%    104999.50000             5.420000              70.780000
# 75%    107499.25000             7.740000              85.200000
# max    109999.00000            10.000000             100.000000
#
#        assignment_score  midterm_score  final_exam_score  participation_score  \
# count      10000.000000   10000.000000      10000.000000         10000.000000
# mean          64.717809      62.322568         64.979987            55.103202
# std           20.052779      21.710555         20.216141            25.955949
# ...

# %% [markdown]
# # function
# A group of related statements that perform a soecific task
# example
# min(),max() (python bult-in function)

# %%
#obtaining the length of the dataframe(number of column)
len(webs)
# Out:
# 10000

# %%
#obtaining the highest index of the dataframe(number of column)
max(webs.index)
# Out:
# 9999

# %%
#obtaining the lowest indexof the dataframe(number of column)
min(webs.index)
# Out:
# 0

# %%
#obtaining the datatype
type(webs)
# Out:
# pandas.core.frame.DataFrame

# %%
# rounding the value of the dataset
round(webs,2)
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %% [markdown]
# # SELECTING ONE COLUMN

# %% [markdown]
# ## SYNTAX 1

# %%
# select a column with [] (preferred way to select a column)
webs['gender']
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3         Male
# 4         Male
#          ...
# 9995    Female
# 9996      Male
# 9997    Female
# 9998    Female
# 9999      Male
# Name: gender, Length: 10000, dtype: object

# %%
# check out the data type of a column
type(webs['gender'])
# Out:
# pandas.core.series.Series

# %%
# series : attribute  and methods
webs['gender'].index
webs['gender'].head()
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3      Male
# 4      Male
# Name: gender, dtype: object

# %% [markdown]
# ## SYNTAX 2

# %%
#select a column with .
webs.gender
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3         Male
# 4         Male
#          ...
# 9995    Female
# 9996      Male
# 9997    Female
# 9998    Female
# 9999      Male
# Name: gender, Length: 10000, dtype: object

# %% [markdown]
# # selecting 2 or more columns

# %%
# selecting 2 columns using[[]]
webs[['gender', 'assignment_score']]
# Out:
#       gender  assignment_score
# 0       Male             36.47
# 1     Female             34.25
# 2       Male             72.29
# 3       Male             97.63
# 4       Male             65.19
# ...      ...               ...
# 9995  Female             60.41
# 9996    Male             62.45
# 9997  Female             67.08
# 9998  Female             97.73
# 9999    Male             93.33
#
# [10000 rows x 2 columns]

# %%
# check out the data type of the selection
type(webs[['gender', 'assignment_score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# select 2 or more column using [[]]
webs[['gender', 'assignment_score','attendance_percentage']]
# Out:
#       gender  assignment_score  attendance_percentage
# 0       Male             36.47                  69.98
# 1     Female             34.25                  84.80
# 2       Male             72.29                  73.76
# 3       Male             97.63                  45.00
# 4       Male             65.19                  51.13
# ...      ...               ...                    ...
# 9995  Female             60.41                  59.65
# 9996    Male             62.45                  83.62
# 9997  Female             67.08                  95.40
# 9998  Female             97.73                  78.24
# 9999    Male             93.33                  97.11
#
# [10000 rows x 3 columns]

# %%
# we cant select 2 or more columns with the "."
#webs.'gender', 'assignment_score' # the . sign reallys does work as well as the [[]]

# %% [markdown]
# # ADDING A COLUMN

# %% [markdown]
# ## adding a new column with a scalar value

# %%
# adding a new column to dataframe
webs['attenton_span_in_class']=70

# %%
webs
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %% [markdown]
# ## ADDING A NEW COLUMN WITH AN ARRAY
# THE DATAFRAME HAS 10000 ROWS SO WE NEED TO CREATE AN ARRAY WITH 10000 ELEMENTS

# %%
# IMPORT NUMPY
import numpy as np

# %%
# CREATE AN ARRAY OF 10000 ELEMENTS
language = np.arange(0,10000)

# %%
#length of array
len(language)
# Out:
# 10000

# %%
# adding a new column to dataframe with an array
webs['language']=language

# %%
webs
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
#create random integer numbers between1 and 100
nt_lang=np.random.randint(1,100,size=10000)

# %%
#min value inclusive and high value exclusive
min(nt_lang)
max(nt_lang)
# Out:
# np.int32(99)

# %%
#adding a new column to dataframe with an array
webs['language']=nt_lang

# %%
webs
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
#adding a new column to dataframe with an array
webs['attenton_span_in_class']=nt_lang

# %%
webs
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
# create random float number between 1 and 100
np.random.uniform(1,100,size=10000)
# Out:
# array([82.99965376,  1.79799306, 61.44535429, ..., 24.14626572,
#        65.54509347, 19.74002705], shape=(10000,))
